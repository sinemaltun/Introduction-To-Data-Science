# %%
import requests
import nltk
import regex as re
import numpy as np
import spacy
import spacy.cli
import requests

from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer

from bs4 import BeautifulSoup

from xmltodict import parse
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA

# %% [markdown]
# # HW3
#
# ## Text Processing
#
# ### Q1
#
# 1. Modify the code I wrote in lecture 8 with what you have learnt in lecture 9 and correctly tokenize the text both on the word and sentence level, and by removing the stopwords. Rewrite the `getSummary` function and all the other functions that it depends by maing these corrections.
#
# 2. Rewrite the code I wrote for `getKeywords` function making the same corrections.
#
# 3. Test your code from parts 1 and 2 on random articles from the Guardian.
#
# 4. Rewrite the `getSubjectGuardian` function for another newspaper in English, and test your code from part 1 and 2 on random articles from this new newspaper.

# %% [markdown]
# Setting the stop words in english

# %%
swEN = stopwords.words('english')

# %% [markdown]
# # Q1.1 & Q1.2
# ## Modifying the Codes
# get_matrix function vectorizes the text allowing us to find the number of sentences and unique words.

# %%
def get_matrix(sentences):
    vectorizer = CountVectorizer()
    return vectorizer.fit_transform(sentences)

# %% [markdown]
# process_text function takes the text as input and basically modifies it. **sent_tokenize** and **word_tokenize** belong to the nltk package and tokenizers' main usage is dividing strings into lists of substrings. I split the whole text into parts of sentences and words so it gets easier working on them.
#
# At the end I want to obtain a summary of the text, so it would look tidy if I updated the words and sentences, making them lower case and getting rid of punctuations such as .,!?.  **re.sub** helps me achieve that
#
# process_text returns *omats: a dictionary consisting of words and sentences that have been updated*

# %%
def process_text(text):
    omats = {'sentences': sent_tokenize(text),
         'words': word_tokenize(text)}
    omats.update({'cleanedSentences': [re.sub(r'[^\p{Letter}\s]','',sentence.lower()) for sentence in omats['sentences']],
              'cleanedWords': [re.sub(r'[^\p{Letter}]','',word.lower()) for word in omats['words']]})
    return omats

# %% [markdown]
# get_summary is the function that summarizes the text by taking the text and k=how many sentences you want in the summary as inputs
#
# The function starts by processing the text using the process_text function explained above. Then the stemmer operation gets activated which helped me find the root of the words in the text, that we updated. After stemming the words I also get rid of stop-words thanks to swEN
#
# Now that my sentences and words are modified it is time to summarize the text. The method here is to find the k number of sentences in the text that have the hightest weights. Those sentences form the summary we are looking for.

# %%
def get_summary(text,k):
    omats=process_text(text)
    stemmer = SnowballStemmer('english')
    stemmed = [stemmer.stem(word) for word in omats['cleanedWords']]
    reduced = [word for word in stemmed if word not in swEN]

    matrix = get_matrix(omats['cleanedSentences'])
    projection = PCA(n_components=1)
    weights = projection.fit_transform(matrix.toarray())
    res = list(zip(weights.transpose()[0],range(112),omats['cleanedSentences']))
    tmp = sorted(res,key=lambda x: x[0],reverse=True)[:k]
    return sorted(tmp, key=lambda x: x[1])

# %% [markdown]
# I also created an url_to_text function that makes the summarization process easier. After accessing the text from the url I have noticed all the news that belong to the same newspaper have the same number of items, for The Guardian that number N is 40. Instead of giving a certain number to pick a link of an article I decided to do that randomly so the function returns different articles each time it runs.
#
# The function returns the text that can be used later on summarization or obtaining the key words.

# %%
def url_to_text(url):
    with requests.get(url) as link:
        raw = parse(link.text)
        
    subject=raw['rss']['channel']['item'] 
    N=len(subject)
    n = np.random.randint(N)
    randomurl=subject[n]['link'] 

    with requests.get(randomurl) as link:
        raw = BeautifulSoup(link.content,'html.parser')
        text=' '.join([x.text for x in raw.find_all('p')])
    return(text)

# %% [markdown]
# get_key_words function takes the text, language of the stop words and k=number of key words as inputs. The whole method is similar to summarization, get_summary function. k number of words that have the highest weights are the key words so they get returned with the weight written next to them

# %%
def get_key_words(text,sw,k):
    omats = process_text(text)
    
    vectorizer = CountVectorizer(stop_words=sw)
    matrix = vectorizer.fit_transform(omats['sentences'])
    words = vectorizer.get_feature_names()
    
    projection = PCA(n_components=1)
    tmp = projection.fit_transform(matrix.transpose().toarray())
    weights = tmp.transpose()[0]
    
    return sorted(zip(weights,words),key=lambda x: x[0], reverse=True)[:k]

# %% [markdown]
# # Q1.3
# ## Testing
# Testing the modified functions on random articles from The Guardian newsfeed. We obtain the summary and key words.

# %%
urlfilm='https://www.theguardian.com/film/rss'
get_summary(url_to_text(urlfilm),5)
# Out:
# [(5.48423739087811,
#   0,
#   'to celebrate her oscar nomination for the power of the dog here are dunsts star turns from gameforadventure girlsnextdoor to enigmatic and melancholy brides and widows a rare unsympathetic outing for kirsten dunst in this muchloved truelife biographical drama about the african american female mathematicians at nasa in the s whose work was vital in getting the us into space'),
#  (2.2452256655000964,
#   21,
#   'the wholesome one was gillian armstrongs spirited and engaging version of the louisa may alcott classic in which dunst played the twinklyeyed younger amy march who was one day to grow up and marry laurie'),
#  (2.6968280194923815,
#   36,
#   'dunsts capacity for poignancy pathos and victimhood is explored in this interesting drama based on a truecrime scandal directed by andrew jarecki who made the documentary capturing the friedmans and went on to made a tv series exploring the real case this was based on'),
#  (2.1522137061397917,
#   39,
#   'dunst was the first among equals playing one of the entrancingly mysterious and tragic sisters in s michigan who fascinate the boys next door in this unsettling emoish romance of doom directed by sofia coppola'),
#  (3.314427698788496,
#   59,
#   'the movie is about the memorytormented lovers jim carrey and kate winslet both giving starquality performances  but it is dunsts poor sad shy mary who crucially recites the lines from pope that give the film its title how happy is the blameless virgins lot')]

# %%
get_key_words(url_to_text(urlfilm),swEN,15)
# Out:
# [(0.9385739551194806, 'actor'),
#  (0.7102122922922125, 'appearance'),
#  (0.710212292292212, 'baton'),
#  (0.710212292292212, 'covid'),
#  (0.710212292292212, 'desperate'),
#  (0.710212292292212, 'dignified'),
#  (0.710212292292212, 'eventually'),
#  (0.710212292292212, 'giving'),
#  (0.710212292292212, 'hand'),
#  (0.710212292292212, 'interesting'),
#  (0.710212292292212, 'jason'),
#  (0.710212292292212, 'lucky'),
#  (0.710212292292212, 'mentioned'),
#  (0.710212292292212, 'momoa'),
#  (0.710212292292212, 'naked')]

# %%
urltech='https://www.theguardian.com/technology/rss'
get_summary(url_to_text(urltech),5)
# Out:
# [(3.5674603390884867,
#   0,
#   'tech giants revenues grew at a sluggish  in the first quarter to bn as shoppers switch back to bricks and mortar amazon announced its first loss since  on thursday as sales slowed costs rose and its investment in electric vehicle company rivian wiped out profits'),
#  (1.174553481463236,
#   2,
#   'the tech giants revenues grew at a sluggish  in the first quarter to bn amazons slowest growth rate in nearly two decades'),
#  (1.8680661107683896,
#   6,
#   'for the current quarter amazon expects operating income between a loss of bn and a gain of bn compared with bn in second quarter of '),
#  (3.5485306360447586,
#   11,
#   'amazon was one of the biggest winners of the pandemic recording huge jumps in sales as consumers moved to shopping online and companies turned to amazon web services aws its cloud computing unit to run their businesses'),
#  (2.442792965314307,
#   16,
#   'the share of retail purchases made online has dropped from  in the second quarter of  to  during the last three months of  according to census bureau data')]

# %%
get_key_words(url_to_text(urltech),swEN,15)
# Out:
# [(7.127470936301366, 'ipad'),
#  (3.9513562167386196, 'tablet'),
#  (3.759951238848723, 'apple'),
#  (3.723413429832697, 'review'),
#  (2.506756901637175, 'pro'),
#  (2.1732536153297284, '10'),
#  (1.9577540992967113, 'costs'),
#  (1.680208906249131, 'stunning'),
#  (1.3522747549766037, '2021'),
#  (1.2623211483627148, 'fire'),
#  (1.2623211483627148, 'hd'),
#  (1.182930018237057, 'm1'),
#  (1.0953109754554753, 'mini'),
#  (0.9817256274457742, 'upgraded'),
#  (0.9815055814936636, 'top')]

# %% [markdown]
# # Q1.4
# ## Extracting Text From UN News
# To work on another newsfeed I decided to go with UN News. The get_subject_un function takes the name of a subject such as women, health, science... and pastes that subject into to structured url. The news with several information (title, link, describtion...) gets returned in the format of an ordered dictionary.

# %%
def get_subject_un(subject):
    with requests.get(f'https://news.un.org/feed/subscribe/en/news/topic/{subject}/feed/rss.xml') as link:
        raw = parse(link.text)
    return raw['rss']['channel']['item']

# %%
get_subject_un('women')
# Out:
# [OrderedDict([('title', 'Tech needs girls, and girls need tech'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117162'),
#               ('description',
#                'More and more young women and girls are highlighting the importance of access and safety in the digital world. Marking International Girls in ICT Day, on Thursday, UN agencies have issued a call to action to ensure equal access to digital learning opportunities.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/28-04-2022-UNICEF-UN0551726-ICT-Day.jpg/image770x420cropped.jpg'),
#                             ('@length', '56418'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117162')])),
#               ('pubDate', 'Thu, 28 Apr 2022 13:09:59 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Rights chief Bachelet backs call for greater women’s role in disarmament talks'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116652'),
#               ('description',
#                'Disarmament research agency UNIDIR\xa0called\xa0on Thursday for more women to take their rightful place in international security discussions – a move that’s been warmly welcomed by the UN High Commissioner for Human Rights,\xa0Michelle Bachelet.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/05-04-22_ART_GarzonClavijo_COLOMBIA_12.jpg/image770x420cropped.jpg'),
#                             ('@length', '72913'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116652')])),
#               ('pubDate', 'Thu, 21 Apr 2022 16:51:32 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Justice critical to fighting sexual violence in conflict'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116192'),
#               ('description',
#                'Women’s rights are human rights, and universal in times of war and peace, a senior UN official told the Security Council on Wednesday, urging ambassadors to ensure accountability for conflict-related sexual violence.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/13-04-2022_UNICEF_Nigeria.jpg/image770x420cropped.jpg'),
#                             ('@length', '54336'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116192')])),
#               ('pubDate', 'Wed, 13 Apr 2022 15:16:29 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'UNHCR calls for better oversight of UK ‘Homes for Ukraine’ scheme'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116162'),
#               ('description',
#                'The UN refugee agency, UNHCR,\xa0has highlighted\xa0the need for “adequate safeguards” and vetting measures to be put in place against the possible exploitation of Ukrainian women, under the United Kingdom’s “Homes for Ukraine” scheme.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/13-04-2022-Unsplash-London-UK.jpg/image770x420cropped.jpg'),
#                             ('@length', '84552'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116162')])),
#               ('pubDate', 'Wed, 13 Apr 2022 12:39:00 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'The key to climate action and sustainable peace? Women’s full and equal participation'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1115272'),
#               ('description',
#                'Women and children increasingly bear the brunt of climate change, which deepens the inequalities and vulnerabilities they already face, such as poverty, violence, lack of opportunities and basic human rights. Yet women are not victims; they are survivors, innovators and solution-multipliers who deserve a real seat at the table. Two Colombian activists tell us why this is true.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/28-03-2022-Alianza-Tejedoras.jpg/image770x420cropped.jpg'),
#                             ('@length', '83616'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1115272')])),
#               ('pubDate', 'Thu, 31 Mar 2022 20:59:19 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                '‘Staggering number’ of unintended pregnancies reveals failure to uphold women’s rights'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1115062'),
#               ('description',
#                'Nearly half of all pregnancies, totalling 121 million each year worldwide, are unintended, according to a new report published on Wednesday by the UN’s sexual and reproductive health agency, UNFPA.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/29-03-2022_UNFPA_Thailand.jpg/image770x420cropped.jpg'),
#                             ('@length', '28875'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1115062')])),
#               ('pubDate', 'Wed, 30 Mar 2022 00:16:07 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Fighting child marriage in India, thanks to school and a mobile phone'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114752'),
#               ('description',
#                'With the help of an innovative mobile phone service, UN agencies are working with the Government of Rajasthan, India, to combat child marriage.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/10-03-22_child_marriage_prevention_India.jpg/image770x420cropped.jpg'),
#                             ('@length', '82739'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114752')])),
#               ('pubDate', 'Sun, 27 Mar 2022 00:06:59 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Mistreatment in childbirth, a human rights and healthcare problem, new study warns'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114512'),
#               ('description',
#                'Women across the world face unacceptable mistreatment during childbirth, according to a new study from the World Health Organization (WHO) and the Human Reproduction Programme (HRP) launched on Wednesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/15-02-2022-World-Bank-Cambodia.jpg/image770x420cropped.jpg'),
#                             ('@length', '36656'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114512')])),
#               ('pubDate', 'Wed, 23 Mar 2022 12:04:12 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Taliban’s backtracking on girls’ education, ‘deeply damaging’'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114482'),
#               ('description',
#                'Following a U-turn over re-opening girls’ secondary schools in Afghanistan on Wednesday, the UN human rights chief shared her “profound frustration and disappointment” that six months after the Taliban seized power, high school girls have yet to return to the classroom.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/23-03-2022_UNICEF_Afghanistan-3.jpg/image770x420cropped.jpg'),
#                             ('@length', '31013'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114482')])),
#               ('pubDate', 'Wed, 23 Mar 2022 10:40:52 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Women and girls deserve to live without violence in ‘safety, dignity and freedom’'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114472'),
#               ('description',
#                'Violence against women and girls may be the world’s “longest, deadliest pandemic,” the UN chief said on Tuesday, during an event focused on the role boys and men need to play, to help eliminate gender-based violence.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/01-03-2022_UNICEF_South-Africa.jpg/image770x420cropped.jpg'),
#                             ('@length', '54363'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114472')])),
#               ('pubDate', 'Tue, 22 Mar 2022 16:55:46 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'South Sudan: ‘hellish existence’ for women and girls, new UN report reveals'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114312'),
#               ('description',
#                'Widespread sexual violence against women and girls in conflict is being fueled by systemic impunity, the United Nations Commission on Human Rights in South Sudan said on Monday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/21-03-2022_UNICEF_South-Sudan.jpg/image770x420cropped.jpg'),
#                             ('@length', '42918'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114312')])),
#               ('pubDate', 'Mon, 21 Mar 2022 11:40:49 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'World must deliver support to Afghans: UN refugee chief'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114102'),
#               ('description',
#                'UN Refugee Agency chief Filippo Grandi called on Thursday for sustained international support for Afghanistan’s people, where the country’s humanitarian crisis is worsening.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/17-03-2022_UNHCR_Afghanistan-01.jpg/image770x420cropped.jpg'),
#                             ('@length', '40442'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114102')])),
#               ('pubDate', 'Thu, 17 Mar 2022 12:20:10 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Gender equality ‘fundamental prerequisite’ for peaceful, sustainable world'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114072'),
#               ('description',
#                'Gender equality is essentially “a question of power” that for millennia, has, “to the detriment of all”, been mostly in the hands of men, the UN chief told a town hall meeting on Wednesday, devoted to the issue.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/assets/2016/03/24031/image770x420cropped.jpg'),
#                             ('@length', '93715'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114072')])),
#               ('pubDate', 'Wed, 16 Mar 2022 15:42:57 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Guterres vows to improve UN’s handling of sexual exploitation and abuse'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114012'),
#               ('description',
#                'Secretary-General António Guterres\xa0released his annual update on the Organization’s efforts to prevent and respond to sexual exploitation and abuse (SEA) on Tuesday, dovetailing with his system-wide\xa0strategy,\xa0launched in 2017, to stamp out incidents by placing victims at the heart of efforts, throughout the system.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/25-11-2020_UNICEF-207365_Uganda.jpg/image770x420cropped.jpg'),
#                             ('@length', '45550'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114012')])),
#               ('pubDate', 'Tue, 15 Mar 2022 20:35:57 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Violence against women in politics marks ‘moral and ethical failure’ - General Assembly President'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113992'),
#               ('description',
#                'Top UN officials on Tuesday gathered with government and civil society representatives to draw attention to the scourge of violence against women worldwide who are involved in politics, which is increasingly seeing women parliamentarians, human rights defenders and electoral observers silenced, and intimidated.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/15-03-2022_UN-News_PGA.jpg/image770x420cropped.jpg'),
#                             ('@length', '74043'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113992')])),
#               ('pubDate', 'Tue, 15 Mar 2022 16:56:44 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'UN on ‘positive trajectory’ towards full gender parity'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113952'),
#               ('description',
#                'Gender equality and women’s rights are essential to a renewed social contract anchored in human rights - the new\xa0Agenda for Peace\xa0- the UN chief told a meeting on Tuesday aimed at advancing women’s leadership worldwide.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/15-03-2022_UN0602687_Indonesia.jpg/image770x420cropped.jpg'),
#                             ('@length', '31517'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113952')])),
#               ('pubDate', 'Tue, 15 Mar 2022 12:45:32 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Women and girls must lead battle against ‘widespread and interlinked crises’'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113872'),
#               ('description',
#                'To forge a sustainable future for us all, “women and girls must be front and centre, leading the way”. Secretary-General António Guterres told the opening session of the Commission on the Status of Women (CSW) on Monday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/26-10-2021-Hawa-Games-Dahab-Gabjenda-Sudan.jpeg/image770x420cropped.jpg'),
#                             ('@length', '63541'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113872')])),
#               ('pubDate', 'Mon, 14 Mar 2022 12:48:06 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title', 'First Person: ‘I speak up for those who cannot’'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113482'),
#               ('description',
#                'Maya Aktar, a garment worker from Bangladesh, represents other migrants employed in the sector, in Jordan. She explains how she became involved in the union movement, and the positive difference this has made to the lives of her members.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Collections/UNHCR/Embargoed+2/28-02-2022_ILO_Jordan-3.jpg/image770x420cropped.jpg'),
#                             ('@length', '35368'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113482')])),
#               ('pubDate', 'Sat, 12 Mar 2022 00:20:33 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Women must be given space to lead if Afghanistan is to find peace: Bachelet'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113742'),
#               ('description',
#                'Whether as peacebuilders, humanitarians or pivotal actors courageously pushing their communities forward, Afghan women must be given the space to lead if the country is to find peace and progress, the UN human rights chief\xa0Michelle Bachelet\xa0stressed in a\xa0statement\xa0on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/26-01-2022-UNICEF-UN0581133-Afghanistan.jpg/image770x420cropped.jpg'),
#                             ('@length', '55841'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113742')])),
#               ('pubDate', 'Thu, 10 Mar 2022 17:59:06 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Investing in women’s empowerment yields major peace, prosperity dividend, Security Council hears'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113552'),
#               ('description',
#                'Investing in women’s economic empowerment yields enormous dividends for peace and prosperity, the head of UN Women told the Security Council on Tuesday, stressing that countries where women are economically marginalized and shut out of the workforce are much more likely to go to war.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/08-03-2022_WFP_Bangladesh.jpg/image770x420cropped.jpg'),
#                             ('@length', '50735'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113552')])),
#               ('pubDate', 'Tue, 08 Mar 2022 14:35:43 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'International Women’s Day: ‘Time is now’ for gender equality'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113532'),
#               ('description',
#                '‘Gender equality today for a sustainable tomorrow’ is the theme for the UN’s commemoration of International Women’s Day on Tuesday, celebrating the work of women and girls in fighting climate change and ending the COVID-19 pandemic.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Collections/UNHCR/Embargoed+2/08-03-2022_Un-Women_Cameroon-1.jpg/image770x420cropped.jpg'),
#                             ('@length', '98987'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113532')])),
#               ('pubDate', 'Tue, 08 Mar 2022 13:25:17 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'First Person: Giving birth during the Ukraine crisis'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113472'),
#               ('description',
#                'Mariia Shostak, a 25-year-old woman living in the Ukrainian capital Kyiv, started having contractions on 24 February, the day the Russian Federation launched a military offensive in Ukraine, and gave birth amid the sounds of air raid sirens.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/06-03-2022_UNFPA-03.jpg/image770x420cropped.jpg'),
#                             ('@length', '32504'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113472')])),
#               ('pubDate', 'Mon, 07 Mar 2022 22:15:16 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                '‘Turn the clock forward on women’s rights’: UN chief’s International Women’s Day message'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113392'),
#               ('description',
#                'Ahead of International Women’s Day, celebrated on 08 March, UN Secretary-General António Guterres has insisted that the world “cannot emerge from the pandemic with the clock spinning backwards on gender equality”.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/16-02-2022_WFP_Women_Garden_Sahel.jpg/image770x420cropped.jpg'),
#                             ('@length', '90739'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113392')])),
#               ('pubDate', 'Mon, 07 Mar 2022 00:15:25 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Restoring safety and dignity to women in Malawi, displaced by Tropical Storm Ana'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1112702'),
#               ('description',
#                'Tropical Storm Ana left a trail of destruction in its wake in Malawi, particularly in hardest-hit southern districts, after it struck the country in late January. The UN Population Fund (UNFPA) has been at the forefront of efforts to help pregnant women and mothers by providing medical supplies, and reproductive services.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/24-02-2021-UNFPA-Malawi-3.JPG/image770x420cropped.jpg'),
#                             ('@length', '85193'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1112702')])),
#               ('pubDate', 'Sun, 06 Mar 2022 00:30:20 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Canada urged to amend transgenerational discriminatory Indian Act'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113262'),
#               ('description',
#                'The UN Committee on the Elimination of Discrimination against Women (CEDAW) called on Thursday, for Canada to fully address long-standing gender-based discrimination in its Indian Act, which continues to affect tens of thousands of descendants of indigenous women today.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/03-03-2022_Indigenous_Canada_Unsplash.jpg/image770x420cropped.jpg'),
#                             ('@length', '76519'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113262')])),
#               ('pubDate', 'Thu, 03 Mar 2022 17:37:26 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'COVID-19: Depression, anxiety soared 25 per cent in a year'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1113162'),
#               ('description',
#                'In the first year of the COVID-19 pandemic, global rates of anxiety and depression increased by a massive 25 per cent, the World Health Organization (WHO) said on Wednesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/02-03-2022_UNICEF_mental-health.jpg/image770x420cropped.jpg'),
#                             ('@length', '31491'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1113162')])),
#               ('pubDate', 'Wed, 02 Mar 2022 13:48:00 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Concern for women and children caught up in Ukraine conflict'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/02/1112942'),
#               ('description',
#                'The intensification of the Russian offensive in Ukraine is having devastating consequences on women and children, senior UN officials have reported.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/28-02-2022_UNICEF_Ukraine-04.jpg/image770x420cropped.jpg'),
#                             ('@length', '49740'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/02/1112942')])),
#               ('pubDate', 'Mon, 28 Feb 2022 17:02:13 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Women building a sustainable future: India’s rural energy pioneers'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/02/1112652'),
#               ('description',
#                'A UN project, in association with one of India’s leading clean energy companies, is training women salt farmers in the Indian state of Gujarat to work in the solar power industry, and build a better life.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/31-01-22_women_training_livelihoods.jpg/image770x420cropped.jpg'),
#                             ('@length', '51700'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/02/1112652')])),
#               ('pubDate', 'Sat, 26 Feb 2022 06:15:16 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Women building a sustainable future: the Kenyan engineer fighting for equality'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/02/1112632'),
#               ('description',
#                'Norah Magero, a Mechanical Engineer and Renewable Energy Expert from Kenya, is helping communities adapt to the changing climate, in the face of gender discrimination.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/16-02-2022-UN-Women-Norah-Magero.jpg/image770x420cropped.jpg'),
#                             ('@length', '66713'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/02/1112632')])),
#               ('pubDate', 'Fri, 25 Feb 2022 00:15:16 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Baby formula marketing ‘pervasive, misleading and aggressive’ – UN report'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/02/1112452'),
#               ('description',
#                'Parents and pregnant women globally are exposed to aggressive marketing for baby formula milk, according to a report launched jointly by two UN agencies on Tuesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/21-02-2022_UNSPLASH.jpg/image770x420cropped.jpg'),
#                             ('@length', '40014'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/02/1112452')])),
#               ('pubDate', 'Tue, 22 Feb 2022 18:50:15 -0500'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/women/feed/rss.xml')]))])]

# %%
get_subject_un('health')
# Out:
# [OrderedDict([('title',
#                'Extreme heat impacting millions across India and Pakistan'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117272'),
#               ('description',
#                'With extreme heat gripping large parts of India and Pakistan, the two countries are working to roll out life-saving health action plans to combat the heatwave, the World Meteorological Organization (WMO) said on Friday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/29-04-2022-UNICEF-UN0380351-elderlywoman-India-heat.jpg/image770x420cropped.jpg'),
#                             ('@length', '63510'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117272')])),
#               ('pubDate', 'Fri, 29 Apr 2022 11:23:48 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'WHO calls for end to ‘insidious’ online marketing of baby formula'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117252'),
#               ('description',
#                'The $55 billion baby formula industry must end exploitative online marketing targeting parents, particularly mothers, the World Health Organization (WHO) said in a new report published on Friday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/21-02-2022-WHO-UNICEF-baby-formular-03.jpg/image770x420cropped.jpg'),
#                             ('@length', '42441'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117252')])),
#               ('pubDate', 'Fri, 29 Apr 2022 10:36:25 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'West Darfur: Health workers, children, among 200 killed in ‘senseless and brutal attacks’'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117212'),
#               ('description',
#                'Recent intercommunal violence in areas of West Darfur, Sudan, that has left scores dead, including two health workers, must stop immediately, a senior official with the World Health Organization (WHO) said on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/assets/2016/01/23596/image770x420cropped.jpg'),
#                             ('@length', '114671'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117212')])),
#               ('pubDate', 'Thu, 28 Apr 2022 16:49:17 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Learn from the pandemic to strengthen workplace safety: UN labour agency'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117142'),
#               ('description',
#                'The COVID-19 pandemic has shown how effective dialogue between employers, workers and governments, is the best way to strengthen safety and health at work, the International Labour Organization (ILO) said in a new report published on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/28-04-2022-ILO-Labour-Algeria.jpg/image770x420cropped.jpg'),
#                             ('@length', '60303'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117142')])),
#               ('pubDate', 'Thu, 28 Apr 2022 11:42:39 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Kinder brand chocolates now linked to salmonella poisoning in 11 countries'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117072'),
#               ('description',
#                'Eleven mainly European countries have now reported salmonella food poisoning, linked to popular “Kinder” chocolate products produced in Belgium, the UN World Health Organization (WHO) said on Wednesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/27-04-2022-Ukraine-chocolate.jpg/image770x420cropped.jpg'),
#                             ('@length', '41160'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117072')])),
#               ('pubDate', 'Wed, 27 Apr 2022 12:37:00 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Ebola vaccination campaign begins in DR Congo to counter new outbreak'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1117032'),
#               ('description',
#                'An\xa0Ebola\xa0vaccination campaign has begun in northwest Democratic Republic of the Congo (DRC), to halt the spread of a deadly new outbreak in the country, where the disease is endemic.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/18-11-2020-UNICEF-UNI312397-DRC-Ebola.jpg/image770x420cropped.jpg'),
#                             ('@length', '66191'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1117032')])),
#               ('pubDate', 'Wed, 27 Apr 2022 08:55:00 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title', 'Working towards a malaria-free world'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116782'),
#               ('description',
#                'Despite the COVID-19 pandemic, the past year has seen “significant breakthroughs in malaria prevention and control”, a senior official of the UN health agency said on Monday, World Malaria Day.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/31-03-2022_UNICEF_South-Sudan.jpg/image770x420cropped.jpg'),
#                             ('@length', '51038'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116782')])),
#               ('pubDate', 'Sun, 24 Apr 2022 20:09:33 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'New Ebola outbreak declared in the Democratic Republic of Congo'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116762'),
#               ('description',
#                'The health authorities of the African nation declared a new outbreak of Ebola after a case was confirmed in Mbandaka, a city in the north-western Equateur Province, the World Health Organization (WHO) reported on Saturday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/assets/2019/03/14-03-2019-Ebola-healthworkers-DRC.jpg/image770x420cropped.jpg'),
#                             ('@length', '119904'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116762')])),
#               ('pubDate', 'Sat, 23 Apr 2022 12:36:45 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'WHO recommends COVID-19 drug and urges transparency around pricing'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116662'),
#               ('description',
#                'A highly successful COVID-19 therapy must be made available to more people, the World Health Organization (WHO) has said, calling for wider distribution and greater transparency surrounding its pricing.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/30-03-2022_UNICEF_India-3.jpg/image770x420cropped.jpg'),
#                             ('@length', '36743'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116662')])),
#               ('pubDate', 'Thu, 21 Apr 2022 19:01:33 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Africa experiencing longest-running decline in COVID-19 infections'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116262'),
#               ('description',
#                'COVID-19 cases in Africa have fallen for the past 16 weeks, and deaths have dropped during the last eight, marking the longest-running decline in infections on the continent since the start of the pandemic, the World Health Organization (WHO) said on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/14-04-2022_UNICEF_Uganda.jpg/image770x420cropped.jpg'),
#                             ('@length', '41460'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116262')])),
#               ('pubDate', 'Thu, 14 Apr 2022 12:56:49 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'COVID-19: Omicron BA.4 and BA.5 variants, not more severe or transmissible, so far'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116182'),
#               ('description',
#                'As the coronavirus which causes COVID-19 continues to evolve, we cannot afford to ‘lose sight’ of the changes, the UN health agency said on Wednesday, warning that lower case numbers and deaths do not necessarily mean ‘lower risk’.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Collections/Embargoed/13-04-2022_IMF_Uganda.jpg/image770x420cropped.jpg'),
#                             ('@length', '76917'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116182')])),
#               ('pubDate', 'Wed, 13 Apr 2022 13:36:01 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'WHO welcomes initiative to combat noncommunicable diseases, responsible for 7 in 10 deaths worldwide'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116092'),
#               ('description',
#                'The World Health Organization (WHO) on Tuesday,\xa0welcomed the setting up\xa0of a\xa0new Heads of State and Government Group to get the world back on track to reduce premature deaths from noncommunicable diseases like diabetes, cancer, heart and lung disease,\xa0by a third\xa0– in line with the Sustainable Development Goals (SDGs) - and promote mental health and well-being.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/13-12-2021_WHO_Ghana-cancer.jpg/image770x420cropped.jpg'),
#                             ('@length', '62464'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116092')])),
#               ('pubDate', 'Tue, 12 Apr 2022 15:49:17 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'COVID-19 vaccine access in conflict areas remains critical'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1116032'),
#               ('description',
#                'Although safe and effective COVID-19 vaccinations are available, the pandemic is still far from over, and countries affected by conflict are in danger of being left behind, the UN Security Council heard on Monday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/11-04-2022_UNICEF_Yemen.jpg/image770x420cropped.jpg'),
#                             ('@length', '61625'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1116032')])),
#               ('pubDate', 'Mon, 11 Apr 2022 18:11:35 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'New COVID wave a reminder pandemic is ‘far from over’: Guterres'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115952'),
#               ('description',
#                'Governments and pharmaceutical companies need to work together in a better way, to deliver vaccines “to every person, everywhere” – not simply in the wealthiest nations,\xa0said the UN chief on Friday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/26-01-2022-PAHO-Colombia-COVID.jpg/image770x420cropped.jpg'),
#                             ('@length', '88661'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115952')])),
#               ('pubDate', 'Fri, 08 Apr 2022 17:08:23 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Ukraine: UN relief chief joins call for probe after ‘horrifying’ visit to Bucha'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115812'),
#               ('description',
#                'The UN’s top humanitarian official has joined the call for an investigation into the killing of hundreds of civilians in Bucha, Ukraine, following a visit to the city on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/07-04-2022_UNOCHA_Ukraine-1.jpg/image770x420cropped.jpg'),
#                             ('@length', '52868'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115812')])),
#               ('pubDate', 'Thu, 07 Apr 2022 16:48:59 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Ukraine war linked to ‘massive malnutrition crisis’ affecting millions in other emergencies'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115762'),
#               ('description',
#                'The war in Ukraine has increased the risk of a “massive malnutrition crisis” for millions of children in other emergencies because of its already huge impact on global food prices, the UN said on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/07-04-2022_UNICEF_Sudan.jpg/image770x420cropped.jpg'),
#                             ('@length', '52378'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115762')])),
#               ('pubDate', 'Thu, 07 Apr 2022 10:51:01 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'World Health Day: Take climate action, take care of each other'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115722'),
#               ('description',
#                'An urgent call to protect health and mitigate the climate crisis was issued by the UN health agency on Wednesday, to mark World Health Day on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/06-04-2022_WHO_LAO-PDR-.jpg/image770x420cropped.jpg'),
#                             ('@length', '93071'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115722')])),
#               ('pubDate', 'Wed, 06 Apr 2022 20:18:51 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Plant health summit aims to boost food security, safeguard human health'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115572'),
#               ('description',
#                'The world’s plant protection body met on Tuesday, aiming to set new plant health standards to both safeguard human wellbeing and preserve food security, according to the UN Food and Agriculture Organization (FAO).'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/05-04-2022_FAO_Chile.jpg/image770x420cropped.jpg'),
#                             ('@length', '61287'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115572')])),
#               ('pubDate', 'Tue, 05 Apr 2022 14:15:05 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Almost everyone now breathing polluted air, warns WHO'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115492'),
#               ('description',
#                'An astonishing 99 per cent of the world’s population breathes polluted air that exceeds internationally approved limits, with negative health impacts kicking in at much lower levels than previously thought, UN medical scientists said on Monday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/19-10-2021-ADB-Mongolia-pollution.jpg/image770x420cropped.jpg'),
#                             ('@length', '75693'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115492')])),
#               ('pubDate', 'Mon, 04 Apr 2022 14:33:03 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'First Person: A first in psychological aid, for Ukraine refugees in Poland'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/04/1115372'),
#               ('description',
#                'Many of the millions of refugees forced to leave Ukraine because of the Russian invasion are traumatized and need mental health support. In one Polish transit site, volunteers like Aurang Zeb Khan, have been trained by the UN migration agency (IOM) to administer psychological first aid.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/30-03-2021_IOM_Ukraine-Poland-01.jpg/image770x420cropped.jpg'),
#                             ('@length', '57625'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/04/1115372')])),
#               ('pubDate', 'Mon, 04 Apr 2022 00:03:40 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'UN health agency launches bid to stop a new global pandemic'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1115172'),
#               ('description',
#                '“Arboviruses” might not be something most of us are familiar with, but for almost four billion people, they’re a deadly threat – which is why the UN health agency on Thursday, launched a plan to prevent them from causing a new pandemic.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/31-03-2022_WHO_mosquito.jpg/image770x420cropped.jpg'),
#                             ('@length', '27244'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1115172')])),
#               ('pubDate', 'Thu, 31 Mar 2022 09:27:47 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'A third of the world remains totally unvaccinated against COVID: Tedros'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1115142'),
#               ('description',
#                'A third of the world’s population has yet to receive a single dose of COVID-19 vaccine, including a shocking 83 per cent of all Africans,\xa0said the\xa0head of the World Health Organization (WHO) on Wednesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/30-03-2022_UNICEF_India-3.jpg/image770x420cropped.jpg'),
#                             ('@length', '36743'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1115142')])),
#               ('pubDate', 'Wed, 30 Mar 2022 17:33:24 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'UN analysis shows link between lack of vaccine equity and widening poverty gap'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114762'),
#               ('description',
#                'New analyses released by the UN Development Programme (UNDP), show that only a tiny proportion of COVID-19 vaccines have been administered in developing countries, leading to a widening gap between rich and poor.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/24-08-20-UNDP-Bangladesh-Children-Mask.jpg/image770x420cropped.jpg'),
#                             ('@length', '40751'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114762')])),
#               ('pubDate', 'Mon, 28 Mar 2022 00:01:42 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'WHO publishes first-ever country estimates on unintended pregnancy, abortion'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114642'),
#               ('description',
#                'Data analysis on unintended pregnancy and abortion from 150 countries has revealed major disparities in accessing sexual and reproductive healthcare, the UN health agency, WHO, said on Thursday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/24-03-2022_UNICEF_Indonesia.jpg/image770x420cropped.jpg'),
#                             ('@length', '49024'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114642')])),
#               ('pubDate', 'Thu, 24 Mar 2022 16:26:35 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Russia’s war on Ukraine, an assault on the world’s vulnerable: Guterres'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114562'),
#               ('description',
#                'The war in Ukraine is not only a “horror unfolding before our eyes”, but also an “assault on some of the most vulnerable people and countries” across the world,\xa0said the UN chief on Wednesday, convening the first meeting of the steering committee which will guide the creation of a new UN crisis response group to help mitigate the worldwide impact of Russia’s invasion.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/23-03-2022_WHO_Ukraine-2.jpg/image770x420cropped.jpg'),
#                             ('@length', '38680'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114562')])),
#               ('pubDate', 'Wed, 23 Mar 2022 16:06:42 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'UN health agency appeals to reverse gains lost in fight against tuberculosis'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114542'),
#               ('description',
#                'World TB Day is marked on 24 March, and this year, the World Health Organization (WHO) has\xa0called\xa0for urgent investment in the fight against tuberculosis, “to save millions more lives”.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/23-03-2022_ILO_India.jpg/image770x420cropped.jpg'),
#                             ('@length', '41463'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114542')])),
#               ('pubDate', 'Wed, 23 Mar 2022 14:57:56 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Mistreatment in childbirth, a human rights and healthcare problem, new study warns'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114512'),
#               ('description',
#                'Women across the world face unacceptable mistreatment during childbirth, according to a new study from the World Health Organization (WHO) and the Human Reproduction Programme (HRP) launched on Wednesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/15-02-2022-World-Bank-Cambodia.jpg/image770x420cropped.jpg'),
#                             ('@length', '36656'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114512')])),
#               ('pubDate', 'Wed, 23 Mar 2022 12:04:12 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Seeds of change in Kenya as farmers lead way on tobacco-free farms'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114502'),
#               ('description',
#                'In Kenya, a trailblazing sustainable agriculture project has helped hundreds of farmers move away from the harmful practice of growing tobacco, in favour of a healthier alternative, the UN\xa0said\xa0on Wednesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/23-03-2022_WHO_Kenya-3.jpg/image770x420cropped.jpg'),
#                             ('@length', '96352'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114502')])),
#               ('pubDate', 'Wed, 23 Mar 2022 12:02:05 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'First Person: Keeping aid flowing during Ukraine’s health crisis'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114442'),
#               ('description',
#                'Jarno Habicht has worked with WHO for the last 19 years and served as WHO Representative in Ukraine since 2018. He explains how WHO prepared for armed conflict in the country, and how it has responded to health-related issues since the Russian invasion.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/22-03-2022_WHO_Jarno-Habicht.jpg/image770x420cropped.jpg'),
#                             ('@length', '77201'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114442')])),
#               ('pubDate', 'Tue, 22 Mar 2022 22:02:31 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))]),
#  OrderedDict([('title',
#                'Haiti: UN agencies warn of ‘unabated’ rise in hunger'),
#               ('link',
#                'https://news.un.org/feed/view/en/story/2022/03/1114422'),
#               ('description',
#                'While humanitarian assistance has been successful in averting a catastrophe, Haiti is experiencing a persistent rise in hunger levels, with many citizens suffering acutely, the World Food Programme (WFP) said on Tuesday.'),
#               ('enclosure',
#                OrderedDict([('@url',
#                              'https://global.unitednations.entermediadb.net/assets/mediadb/services/module/asset/downloads/preset/Libraries/Production+Library/22-03-2022_WFP_Haiti-3.jpg/image770x420cropped.jpg'),
#                             ('@length', '51452'),
#                             ('@type', 'image/jpeg')])),
#               ('guid',
#                OrderedDict([('@isPermaLink', 'true'),
#                             ('#text',
#                              'https://news.un.org/feed/view/en/story/2022/03/1114422')])),
#               ('pubDate', 'Tue, 22 Mar 2022 11:57:18 -0400'),
#               ('source',
#                OrderedDict([('@url',
#                              'https://news.un.org/feed/subscribe/en/news/topic/health/feed/rss.xml')]))])]

# %% [markdown]
# In order to get the summary and key words from an UN News article, I pick a random link from the ordered dictionary that will take me to the article on that particular subject. Then I transform it into a text. Sending the text to the get_summary and get_key_words functions I get returned the results with no problem.
#
# I completed my test on women and health subjects

# %%
subject=get_subject_un('women')
N=len(subject)
n = np.random.randint(N)
randomurl=subject[n]['link'] 
with requests.get(randomurl) as link:
    raw = BeautifulSoup(link.content,'html.parser')
    text=' '.join([x.text for x in raw.find_all('p')])

# %%
get_summary(text,5)
# Out:
# [(1.5012413776560838,
#   2,
#   'the denial of education violates the human rights of women and girls\xa0 un human rights chief\n although high schools were set to open their doors to girls nationwide taliban authorities reportedly reversed the move early on wednesday pending a ruling made on the uniforms they must wear'),
#  (1.826642436623655,
#   10,
#   'the women told her that they have information solutions and the capability to help chart a way out of this economic humanitarian and human rights crisis in afghanistan they insisted upon the equal right to quality education at the primary secondary and tertiary levels and were hopefully awaiting the reopening of schools today'),
#  (4.232498168659646,
#   13,
#   'statement by unicefchief httpstcocflqbq as afghan citizens suffer the impacts of multiple intersecting crises the senior un official described the decision as being of grave concern disempowering half of afghanistans population is counterproductive and unjust ms bachelet said adding that structural discrimination such as this is also deeply damaging for the countrys prospects of future recovery and development she called on the taliban to respect all girls rights to education and to open schools for all students without discrimination or further delay'),
#  (9.041316612350654,
#   16,
#   'it did not take long for their hopes to be shattered according to ms russell the decision meant that an entire generation of adolescent girls is being denied their right to an education androbbed of the opportunity to gain the skills they need to build their futures she urged the\xa0de facto\xa0authorities to honour their commitment to girls education without any further delay and appealed to community leaders in every corner of the country to support the education of adolescent girls'),
#  (7.4480468408143565,
#   19,
#   'the un assistance mission in afghanistan unama responded to the news by tweeting that it deplores todays reported announcement by the taliban that they are further extending their indefinite ban on female students above the th grade being permitted to return school seven months after afghanistans fall to the taliban the security council on thursday renewed the mandate of the un special political mission in the country charging it with a robust set of priorities ranging from coordinating humanitarian aid delivery to human rights monitoring and facilitating dialogue')]

# %%
get_key_words(text,swEN,15)
# Out:
# [(4.795481843686726, 'girls'),
#  (3.86192741428134, 'education'),
#  (1.347043583874491, 'rights'),
#  (1.1596870829931816, 'women'),
#  (1.0709204456112458, 'authorities'),
#  (0.9820401035093853, 'adolescent'),
#  (0.9508450648400528, 'schools'),
#  (0.9323357224155904, 'ms'),
#  (0.7205837901071626, 'human'),
#  (0.7201263064658585, 'country'),
#  (0.7164987667413226, 'denial'),
#  (0.7164987667413226, 'violates'),
#  (0.7159934255811642, 'de'),
#  (0.7159934255811642, 'facto'),
#  (0.7057797856315318, 'decision')]

# %%
subject=get_subject_un('health')
N=len(subject)
n = np.random.randint(N)
randomurl=subject[n]['link'] 
with requests.get(randomurl) as link:
    raw = BeautifulSoup(link.content,'html.parser')
    text=' '.join([x.text for x in raw.find_all('p')])

# %%
get_summary(text,5)
# Out:
# [(1.4647298049021389,
#   0,
#   'subscribe audio hub an\xa0ebola\xa0vaccination campaign has begun in northwest democratic republic of the congo drc to halt the spread of a deadly new outbreak in the country where the disease is endemic'),
#  (3.392381578696105,
#   2,
#   'drc  is kicking off ebola vaccination todaythe vaccination is taking place in mbandaka capital city of equateur province in the northwest to halt the spread of the virus following an outbreak which has claimed two lives since  april httpstcovyrlrdk pictwittercomncdssksmy it follows the deaths of two people from ebola since  april'),
#  (1.0098786558061352,
#   4,
#   'with effective vaccines at hand and the experience of drc health workers in ebola response we can quickly change the course of this outbreak for the better said dr matshidiso moeti the un agencys regional director for africa'),
#  (6.042367832178028,
#   11,
#   'national health authorities are also crucial to the effort including the national institute for biomedical research which has completed an analysis of a sample from the first confirmed case results of which show that the new outbreak\xa0indicates a new strain of ebola the result of a spillover event from the host or animal reservoir who said'),
#  (1.6964241171252952,
#   13,
#   'the health authorities of the african nation declared a new outbreak of ebola after a case was confirmed in mbandaka a city in the northwestern equateur province the world health organization who reported on saturday')]

# %%
get_key_words(text,swEN,15)
# Out:
# [(2.505923889152669, 'ebola'),
#  (1.9461584765817714, 'since'),
#  (1.832298644178452, 'vaccination'),
#  (1.5427081582019126, '21'),
#  (1.5427081582019126, 'april'),
#  (1.5427081582019126, 'two'),
#  (1.1236444276261104, 'mbandaka'),
#  (1.0274339079053798, 'city'),
#  (0.9982952379896448, 'outbreak'),
#  (0.9698325722201069, 'equateur'),
#  (0.9698325722201069, 'province'),
#  (0.8785577646298885, 'drc'),
#  (0.8734209888405879, 'lives'),
#  (0.8420779504411995, 'north'),
#  (0.8253452568476091, 'halt')]

# %% [markdown]
# ### Q2
#
# Write a function that returns all named entities (proper names, country names, corporation names only) from a URL. Function should take the URL as the input and must return the list of named entities from that URL. Test your code on random articles from the Guardian. Don't use the NLTK's NER that I demonstrated during the lecture. Use the SpaCY's NER function.

# %% [markdown]
# I load the spacy English tokenizer, tagger, parser and NER

# %%
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# The get_names function first takes the url in rss form and picks a random article's link. Through that link the text form of the article gets created.
#
# Essentially, res is the article we want to work with. By putting it in calling Named Entity Recognition (NER), forming res=NER(article) we can access the name entities of the article. This would have been enough but I wanted to filter the entities that gets printed out. I only wanted to access proper names, country names, corporation names so by checking the website cited below I completed the filtering.
#
# > https://newscatcherapi.com/blog/named-entity-recognition-with-spacy

# %%
def get_names(url):
    with requests.get(url) as link:
        raw = parse(link.text)
        
    subject=raw['rss']['channel']['item'] 
    N=len(subject)
    n = np.random.randint(N)
    randomurl=subject[n]['link'] 

    with requests.get(randomurl) as link:
        raw = BeautifulSoup(link.content,'html.parser')
        article=' '.join([x.text for x in raw.find_all('p')])

    
    res=NER(article)

    
    for ent in res.ents:
        if ent.label_ in ['PERSON','GPE','LOC','EVENT','FAC','LANGUAGE','LAW','NORP','WORK_OF_ART']:
            print(ent.text)

# %% [markdown]
# I tested the get_names function on The Guardian's technology, fashion and film segments.

# %%
urltech='https://www.theguardian.com/technology/rss'
get_names(urltech)
# Out:
# The Legend of Zelda, Battlefield 2042
# Metal Gear Solid
# Video Games Live
# Los Angeles
# Beijing
# Sydney
# London
# The Legend of Zelda
# David Pickard
# Robert Ames
# Ames
# Hildur Guðnadóttir
# Oscar
# Joker
# Sam Slater
# Guðnadóttir
# Ames
# Yoko Shimomura
# Brahms
# Mahler

# %%
urlfashion='https://www.theguardian.com/fashion/rss'
get_names(urlfashion)
# Out:
# Baguette
# American
# British
# Wrapuette
# Baguette
# Gucci
# UK
# Italian
# Savile Row
# Natalie Hartley
# Baguette
# Hartley
# Baguette
# Baguette
# Silvia Venturini Fendi
# Laird Borrelli-Persson
# French
# Chillie London
# Wrapuette
# Hartley
# Gen
# Jane Collins

# %%
urlfilm='https://www.theguardian.com/film/rss'
get_names(urlfilm)
# Out:
# Ivan Reitman
# Hollywood
# Ernst Lubitsch
# Gregory La Cava
# Bill Murray
# Dan Aykroyd
# Harold Ramis
# Ivan Reitman
# London
# Jason
# Reitman
# Canadian
# Meatballs
# Bill Murray
# Reitman
# Ghostbusters and Ghostbusters II
# Hollywood
# Arnold Schwarzenegger
# Kindergarten Cop
# Arnie

# %% [markdown]
# ### Q3
#
# 1. Write a function that returns the most positive and the most negative sentences from a text. The function must take the text as the input and must return a 2-tuple: the first element as the most positive and the second as the most negative sentence with their polarity scores.
#
# 2. Test your function on random articles from the Guardian.

# %% [markdown]
# # Q3.1
# ## Positive-Negative Function

# %% [markdown]
# I reused the url_to_text function created earlier to gain access to the text from its url

# %%
def url_to_text(url):
    with requests.get(url) as link:
        raw = parse(link.text)
        
    subject=raw['rss']['channel']['item'] 
    N=len(subject)
    n = np.random.randint(N)
    randomurl=subject[n]['link'] 

    with requests.get(randomurl) as link:
        raw = BeautifulSoup(link.content,'html.parser')
        text=' '.join([x.text for x in raw.find_all('p')])
    return(text)

# %% [markdown]
# The pos_neg function takes the text as input. Then set my analyzer as the SentimentIntensityAnalyzer from the Natural Language Toolkit (NLTK). This analyzer has a function that calculates the polarity scores.
#
# The sent_tokenize function helps me split the test into sententes, does the tokenization. Then, the polarity score of each of those sentences get calculated. The polarity scores are positive, neutral, negative.
#
# > The Compound score is a metric that calculates the sum of all the lexicon ratings which have been normalized between -1(most extreme negative) and +1 (most extreme positive).
# https://www.geeksforgeeks.org/python-sentiment-analysis-using-vader/
#
# The for loops look for the sentence that has the highest value of positive or negative polarity score, then keeps the sentence and the number i, which represents how manyth sentence it is, in order to print all the polarity scores of that sentence.
#
# Putting the sentence along with it's polarity scores into a tuple, the final tuple with the most positive and negative sentence with it's scores gets returned.

# %%
def pos_neg(text):
    analyzer = SentimentIntensityAnalyzer()
    
    sentences = sent_tokenize(text)
    a=[(x,analyzer.polarity_scores(x)) for x in sentences]
    
    maxneg=a[0][1]['neg']
    maxpos=a[0][1]['pos']
    for i in range(len(a)):
        if (a[i][1]['neg']>=maxneg):
            maxneg=a[i][1]['neg']
            negsentence=a[i][0]
            negvalue=i
            
    for i in range(len(a)):
        if (a[i][1]['pos']>=maxpos):
            maxneg=a[i][1]['pos']
            possentence=a[i][0]
            posvalue=i

    tuple1=(negsentence,a[negvalue][1])
    tuple2=(possentence,a[posvalue][1])
    tuple3=(tuple1,tuple2)
    return(tuple3)

# %% [markdown]
# # Q3.2
# ## Testing
# I tested my function on random articles from The Guardian's film, economy and technology segments. I obtained the sentences with the most negative and the most positive polarity scores.

# %%
urlfilm='https://www.theguardian.com/film/rss'
text=url_to_text(urlfilm)
pos_neg(text)
# Out:
# (('It’s a painful probing of a psychological wound in her parents’ lives: the death of Quirijns’s elder sister in a drowning accident.',
#   {'neg': 0.382, 'neu': 0.618, 'pos': 0.0, 'compound': -0.872}),
#  ('There are points of similarity in their respective cases, and the film duly touches on them, but it sounds glib and it’s impossible not to wonder if Quirijns would not have been better off concentrating on the one story that is centrally important to her, her own, and digging deeper into that.',
#   {'neg': 0.055, 'neu': 0.872, 'pos': 0.073, 'compound': -0.0023}))

# %%
urleco='https://www.theguardian.com/economy/rss'
text=url_to_text(urleco)
pos_neg(text)
# Out:
# (('Rightwing free speech absolutists celebrated the acquisition, while many on the left sounded alarm bells about the implications of one wealthy man taking control of such an influential communication platform.',
#   {'neg': 0.06, 'neu': 0.628, 'pos': 0.312, 'compound': 0.875}),
#  ('But we increasingly need our readers to fund our work.',
#   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}))

# %%
urltech='https://www.theguardian.com/technology/rss'
text=url_to_text(urltech)
pos_neg(text)
# Out:
# (('“For Instagram, one of the most alarming things we observed was that its algorithm is actually recommending accounts that are offering fake sanitary or vaccination services, so if you are a person who is following a couple of accounts with Covid disinformation or anti-vax content, your algorithm will recommend more accounts offering fake passes.',
#   {'neg': 0.137, 'neu': 0.821, 'pos': 0.043, 'compound': -0.6697}),
#  ('Exclusive: fake passes often promoted on mainstream social media platforms, study shows Anti-vaxxers in France are buying fake vaccine passes online to get around the country’s Covid restrictions, which are often promoted on mainstream social media platforms, research has revealed.',
#   {'neg': 0.128, 'neu': 0.725, 'pos': 0.147, 'compound': -0.0258}))
